% %%
a = [2, 4, 5; 5, 8, 9]
a * 3
% Out:
% a =
%
%    2   4   5
%    5   8   9
%
% ans =
%
%     6   12   15
%    15   24   27

% %%
x = -10:0.1:10;
plot (x, sin (x));
xlabel ("x");
ylabel ("sin (x)");
title ("Simple 2-D Plot");
